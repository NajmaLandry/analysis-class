# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#load csv file with headers 
location = "Datasets/DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# 0        4201.0  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 1        4201.0  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 2        4201.0  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 3        4201.0  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 4        4201.0  004201 2006  Ward 2     152 -77.040429  38.914881       NW
#
# [5 rows x 49 columns]

# %%
df.tail(3)
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 158954      158954       2          0  Forced Air  Y        NaN      4      2
# 158955      158955       1          0   Warm Cool  Y        NaN      2      0
# 158956      158956       1          0   Warm Cool  Y        NaN      2      0
#
#            AYB  YR_RMDL   ...     LONGITUDE       ASSESSMENT_NBHD  \
# 158954  1920.0   2007.0   ...     -77.01942            Old City 2
# 158955  1965.0      NaN   ...     -77.01823  Southwest Waterfront
# 158956  1965.0      NaN   ...     -77.01823  Southwest Waterfront
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# 158954   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158955                NaN       11000.0          NaN  Ward 6     504
# 158956                NaN       11000.0          NaN  Ward 6     504
#
#                 X          Y QUADRANT
# 158954 -77.019422  38.911848       NW
# 158955 -77.018232  38.872961       SW
# 158956 -77.018232  38.872961       SW
#
# [3 rows x 49 columns]

# %%
df['PRICE'].max()
# Out:
# 137427545.0

# %%
df['PRICE'].min()
# Out:
# 1.0

# %%
df['PRICE'].median()
# Out:
# 399999.0

# %%
df['PRICE'].mean()
# Out:
# 931351.5949336156

# %%
df['GRADE'].value_counts()
# Out:
# Average          37357
# Above Average    32101
# Good Quality     20800
# Very Good         8976
# Excellent         3390
# Superior          2634
# Exceptional-A      818
# Exceptional-B      278
# Fair Quality       150
# Exceptional-C       92
# Exceptional-D       75
# No Data             19
# Low Quality          6
# Name: GRADE, dtype: int64

# %%
df['AYB'].value_counts()
# Out:
# 1900.0    8967
# 1925.0    5129
# 1910.0    4563
# 1940.0    4316
# 1923.0    3724
# 1927.0    3707
# 1941.0    3420
# 1926.0    3117
# 1942.0    3058
# 1939.0    2849
# 1950.0    2696
# 1937.0    2690
# 1936.0    2553
# 2007.0    2291
# 1908.0    2274
# 1912.0    2272
# 1938.0    2246
# 1928.0    2190
# 1909.0    2154
# 2005.0    2146
# 1951.0    2086
# 1947.0    2058
# 1920.0    2019
# 2006.0    2019
# 1890.0    1976
# 1930.0    1884
# 1929.0    1838
# 1960.0    1816
# 1948.0    1808
# 1911.0    1807
#           ...
# 1819.0       2
# 1835.0       2
# 1861.0       2
# 1847.0       2
# 1849.0       2
# 1824.0       2
# 1808.0       1
# 1793.0       1
# 1765.0       1
# 1866.0       1
# 1782.0       1
# 1784.0       1
# 1785.0       1
# 1787.0       1
# 1788.0       1
# 1854.0       1
# 1791.0       1
# 1851.0       1
# 1834.0       1
# 1795.0       1
# 1822.0       1
# 1797.0       1
# 1799.0       1
# 1833.0       1
# 1846.0       1
# 1844.0       1
# 1842.0       1
# 1841.0       1
# 1806.0       1
# 2019.0       1
# Name: AYB, Length: 220, dtype: int64

# %%
df['STRUCT'].groupby(df['AYB']).mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.SeriesGroupBy object at 0x000001DCDDC05DD8>>

# %%
df['GBA'].unique()
# Out:
# array([ 2522.,  2567.,  2484., ...,  5712.,  4995.,    nan])

# %%
#find missing values 
filename = "datasets/DC_Properties.csv"
df_missing = pd.read_csv(filename)

df_missing.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# 0        4201.0  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 1        4201.0  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 2        4201.0  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 3        4201.0  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 4        4201.0  004201 2006  Ward 2     152 -77.040429  38.914881       NW
#
# [5 rows x 49 columns]

# %%
df_missing.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fb07c8028e23> in <module>()
# ----> 1 df_missing.isnull().sum()
#
# NameError: name 'df_missing' is not defined

# %%
missing = df_missing['SALEDATE'].isnull()
df_missing.loc[missing]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 4                4       2          1      Warm Cool  Y        1.0     11
# 10              10       3          0     Forced Air  N        3.0     12
# 12              12       2          0  Hot Water Rad  N        2.0      9
# 13              13       2          0      Warm Cool  Y        2.0     11
# 15              15       2          1      Warm Cool  Y        2.0      9
# 26              26       1          0  Hot Water Rad  N        1.0     10
# 30              30       2          1     Forced Air  Y        2.0      8
# 33              33       2          1     Forced Air  Y        2.0     10
# 36              36       3          1      Warm Cool  Y        2.0     10
# 38              38       3          1     Forced Air  Y        2.0      9
# 39              39       3          1      Warm Cool  Y        2.0      9
# 51              51       3          0     Forced Air  Y        3.0      9
# 53              53       2          1      Warm Cool  Y        2.0      7
# 57              57       1          0  Hot Water Rad  Y        1.0      6
# 60              60       2          0  Hot Water Rad  N        2.0      9
# 63              63       3          1     Forced Air  Y        2.0     13
# 80              80       2          1      Warm Cool  Y        2.0     11
# 83              83       2          1      Warm Cool  Y        2.0     11
# 87              87       1          1  Hot Water Rad  Y        2.0      6
# 88              88       2          2  Hot Water Rad  N        1.0      8
# 104            104       4          1      Warm Cool  Y        1.0     11
# 109            109       2          1      Warm Cool  Y        1.0     13
# 111            111       2          2      Warm Cool  Y        2.0     10
# 125            125       3          1      Warm Cool  Y        2.0     10
# 147            147       1          1      Warm Cool  Y        1.0      5
# 155            155       1          1      Warm Cool  Y        1.0      6
# 159            159       2          0      Warm Cool  Y        1.0      6
# 164            164       1          1      Warm Cool  Y        1.0      6
# 174            174       2          0  Hot Water Rad  N        1.0      8
# 176            176       1          0  Hot Water Rad  N        1.0      9
# ...            ...     ...        ...            ... ..        ...    ...
# 158673      158673       2          1      Warm Cool  Y        NaN      6
# 158674      158674       2          2      Warm Cool  Y        NaN     10
# 158681      158681       3          0      Warm Cool  Y        NaN      5
# 158696      158696       3          0      Warm Cool  Y        NaN      5
# 158698      158698       3          0      Warm Cool  Y        NaN      5
# 158718      158718       2          1      Warm Cool  Y        NaN      5
# 158721      158721       3          0      Warm Cool  Y        NaN      5
# 158723      158723       3          0      Warm Cool  Y        NaN      5
# 158728      158728       2          1      Warm Cool  Y        NaN      5
# 158832      158832       2          0      Warm Cool  Y        NaN      5
# 158837      158837       1          0      Warm Cool  Y        NaN      4
# 158840      158840       1          0      Warm Cool  Y        NaN      4
# 158842      158842       1          0      Warm Cool  Y        NaN      3
# 158847      158847       2          0      Warm Cool  Y        NaN      6
# 158848      158848       1          0      Warm Cool  Y        NaN      3
# 158849      158849       1          0      Warm Cool  Y        NaN      3
# 158859      158859       2          0      Warm Cool  Y        NaN      6
# 158860      158860       1          0      Warm Cool  Y        NaN      4
# 158863      158863       1          0      Warm Cool  Y        NaN      3
# 158866      158866       1          0      Warm Cool  Y        NaN      4
# 158872      158872       1          0      Warm Cool  Y        NaN      4
# 158883      158883       1          0      Warm Cool  Y        NaN      4
# 158913      158913       2          1     Forced Air  Y        NaN      4
# 158917      158917       2          1     Forced Air  Y        NaN      4
# 158922      158922       1          0        Ht Pump  Y        NaN      5
# 158923      158923       2          0        Ht Pump  Y        NaN      6
# 158925      158925       2          0        Ht Pump  Y        NaN      6
# 158937      158937       1          0     Forced Air  Y        NaN      4
# 158941      158941       1          0     Forced Air  Y        NaN      4
# 158942      158942       2          0     Forced Air  Y        NaN      7
#
#         BEDRM     AYB  YR_RMDL   ...     LONGITUDE       ASSESSMENT_NBHD  \
# 4           3  1913.0   2012.0   ...    -77.039361            Old City 2
# 10          5  1890.0   1950.0   ...    -77.040760            Old City 2
# 12          5  1894.0   1979.0   ...    -77.039569            Old City 2
# 13          5  1885.0   1979.0   ...    -77.039644            Old City 2
# 15          4  1908.0   1990.0   ...    -77.039784            Old City 2
# 26          5  1900.0   2004.0   ...    -77.034258            Old City 2
# 30          3  1900.0   2004.0   ...    -77.033993            Old City 2
# 33          3  1900.0   2004.0   ...    -77.033640            Old City 2
# 36          4  1800.0   1975.0   ...    -77.033431            Old City 2
# 38          4  1800.0   2004.0   ...    -77.033294            Old City 2
# 39          4  1976.0      NaN   ...    -77.033225            Old City 2
# 51          3  1890.0   2004.0   ...    -77.033361            Old City 2
# 53          4  1890.0   1978.0   ...    -77.033644            Old City 2
# 57          3  1885.0      NaN   ...    -77.035813            Old City 2
# 60          2  1870.0   1980.0   ...    -77.034766            Old City 2
# 63          5  1900.0   1999.0   ...    -77.036164            Old City 2
# 80          3  1979.0      NaN   ...    -77.037858            Old City 2
# 83          3  1979.0      NaN   ...    -77.037915            Old City 2
# 87          3  1865.0      NaN   ...    -77.037394            Old City 2
# 88          4  1865.0      NaN   ...    -77.037471            Old City 2
# 104         6  1900.0      NaN   ...    -77.046366            Old City 2
# 109         5  1890.0   2004.0   ...    -77.045920            Old City 2
# 111         5  1885.0      NaN   ...    -77.046061            Old City 2
# 125         5  1922.0   2007.0   ...    -77.045969            Old City 2
# 147         2  1939.0      NaN   ...    -77.041986            Old City 2
# 155         3  1907.0   2012.0   ...    -77.038703            Old City 2
# 159         3  1900.0      NaN   ...    -77.038697            Old City 2
# 164         3  1880.0      NaN   ...    -77.039058            Old City 2
# 174         4  1900.0      NaN   ...    -77.034288            Old City 2
# 176         2  1895.0   2008.0   ...    -77.032450            Old City 2
# ...       ...     ...      ...   ...           ...                   ...
# 158673      2  1961.0      NaN   ...    -77.014271  Southwest Waterfront
# 158674      4  1961.0      NaN   ...    -77.014271  Southwest Waterfront
# 158681      2  1967.0      NaN   ...    -77.016301  Southwest Waterfront
# 158696      2  1967.0      NaN   ...    -77.016301  Southwest Waterfront
# 158698      2  1967.0      NaN   ...    -77.016301  Southwest Waterfront
# 158718      2  1967.0      NaN   ...    -77.016301  Southwest Waterfront
# 158721      2  1967.0      NaN   ...    -77.016301  Southwest Waterfront
# 158723      2  1967.0      NaN   ...    -77.016301  Southwest Waterfront
# 158728      2  1967.0      NaN   ...    -77.016301  Southwest Waterfront
# 158832      2  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158837      2  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158840      2  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158842      1  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158847      3  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158848      1  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158849      1  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158859      3  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158860      2  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158863      1  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158866      2  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158872      2  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158883      2  1967.0      NaN   ...    -77.020322  Southwest Waterfront
# 158913      2  2014.0      NaN   ...    -77.019274            Old City 2
# 158917      2  2014.0      NaN   ...    -77.019274            Old City 2
# 158922      2  1993.0   1993.0   ...    -77.019274            Old City 2
# 158923      3  1993.0   1993.0   ...    -77.019274            Old City 2
# 158925      3  1993.0   1993.0   ...    -77.019274            Old City 2
# 158937      2  1992.0   1992.0   ...    -77.019420            Old City 2
# 158941      2  1992.0   1992.0   ...    -77.019420            Old City 2
# 158942      4  1992.0   1992.0   ...    -77.019420            Old City 2
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# 4        040 D Old City 2        4201.0  004201 2006  Ward 2     152
# 10       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 12       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 13       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 15       040 D Old City 2        4201.0  004201 2005  Ward 2     152
# 26       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 30       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 33       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 36       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 38       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 39       040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 51       040 E Old City 2        5201.0  005201 4002  Ward 2     208
# 53       040 E Old City 2        5201.0  005201 4002  Ward 2     208
# 57       040 E Old City 2        4300.0  004300 2006  Ward 2     191
# 60       040 E Old City 2        4300.0  004300 2006  Ward 2     191
# 63       040 E Old City 2        4300.0  004300 2006  Ward 2     191
# 80       040 D Old City 2        4201.0  004201 1002  Ward 2     176
# 83       040 D Old City 2        4201.0  004201 1002  Ward 2     176
# 87       040 D Old City 2        4201.0  004201 1006  Ward 2     177
# 88       040 D Old City 2        4201.0  004201 1006  Ward 2     177
# 104      040 D Old City 2        5500.0  005500 1001  Ward 2      92
# 109      040 D Old City 2        5500.0  005500 1005  Ward 2      93
# 111      040 D Old City 2        5500.0  005500 1005  Ward 2      93
# 125      040 D Old City 2        5500.0  005500 1004  Ward 2      93
# 147      040 D Old City 2        4202.0  004202 1008  Ward 2     134
# 155      040 D Old City 2        4201.0  004201 2000  Ward 1     149
# 159      040 D Old City 2        4201.0  004201 2000  Ward 1     149
# 164      040 D Old City 2        4201.0  004201 2002  Ward 1     150
# 174      040 E Old City 2        5201.0  005201 4003  Ward 2     208
# 176      040 E Old City 2        5201.0  005201 4002  Ward 2     208
# ...                   ...           ...          ...     ...     ...
# 158673                NaN       10500.0          NaN  Ward 6     540
# 158674                NaN       10500.0          NaN  Ward 6     540
# 158681                NaN       11000.0          NaN  Ward 6     546
# 158696                NaN       11000.0          NaN  Ward 6     546
# 158698                NaN       11000.0          NaN  Ward 6     546
# 158718                NaN       11000.0          NaN  Ward 6     546
# 158721                NaN       11000.0          NaN  Ward 6     546
# 158723                NaN       11000.0          NaN  Ward 6     546
# 158728                NaN       11000.0          NaN  Ward 6     546
# 158832                NaN       10200.0          NaN  Ward 6     468
# 158837                NaN       10200.0          NaN  Ward 6     468
# 158840                NaN       10200.0          NaN  Ward 6     468
# 158842                NaN       10200.0          NaN  Ward 6     468
# 158847                NaN       10200.0          NaN  Ward 6     468
# 158848                NaN       10200.0          NaN  Ward 6     468
# 158849                NaN       10200.0          NaN  Ward 6     468
# 158859                NaN       10200.0          NaN  Ward 6     468
# 158860                NaN       10200.0          NaN  Ward 6     468
# 158863                NaN       10200.0          NaN  Ward 6     468
# 158866                NaN       10200.0          NaN  Ward 6     468
# 158872                NaN       10200.0          NaN  Ward 6     468
# 158883                NaN       10200.0          NaN  Ward 6     468
# 158913   040 G Old City 2        4801.0          NaN  Ward 6     475
# 158917   040 G Old City 2        4801.0          NaN  Ward 6     475
# 158922   040 G Old City 2        4801.0          NaN  Ward 6     475
# 158923   040 G Old City 2        4801.0          NaN  Ward 6     475
# 158925   040 G Old City 2        4801.0          NaN  Ward 6     475
# 158937   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158941   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158942   040 B Old City 2        4801.0          NaN  Ward 6     477
#
#                 X          Y QUADRANT
# 4      -77.040429  38.914881       NW
# 10     -77.040429  38.914881       NW
# 12     -77.040429  38.914881       NW
# 13     -77.040429  38.914881       NW
# 15     -77.040429  38.914881       NW
# 26     -77.033366  38.911716       NW
# 30     -77.033366  38.911716       NW
# 33     -77.033366  38.911716       NW
# 36     -77.033366  38.911716       NW
# 38     -77.033366  38.911716       NW
# 39     -77.033366  38.911716       NW
# 51     -77.033366  38.911716       NW
# 53     -77.033366  38.911716       NW
# 57     -77.035454  38.914956       NW
# 60     -77.035454  38.914956       NW
# 63     -77.035454  38.914956       NW
# 80     -77.037830  38.916190       NW
# 83     -77.037830  38.916190       NW
# 87     -77.037221  38.915033       NW
# 88     -77.037221  38.915033       NW
# 104    -77.046148  38.913145       NW
# 109    -77.045889  38.912003       NW
# 111    -77.045889  38.912003       NW
# 125    -77.045889  38.912003       NW
# 147    -77.042719  38.912019       NW
# 155    -77.038764  38.918277       NW
# 159    -77.038764  38.918277       NW
# 164    -77.039567  38.917462       NW
# 174    -77.033366  38.911716       NW
# 176    -77.033366  38.911716       NW
# ...           ...        ...      ...
# 158673 -77.014273  38.880828       SW
# 158674 -77.014273  38.880828       SW
# 158681 -77.016303  38.874797       SW
# 158696 -77.016303  38.874797       SW
# 158698 -77.016303  38.874797       SW
# 158718 -77.016303  38.874797       SW
# 158721 -77.016303  38.874797       SW
# 158723 -77.016303  38.874797       SW
# 158728 -77.016303  38.874797       SW
# 158832 -77.020324  38.880130       SW
# 158837 -77.020324  38.880130       SW
# 158840 -77.020324  38.880130       SW
# 158842 -77.020324  38.880130       SW
# 158847 -77.020324  38.880130       SW
# 158848 -77.020324  38.880130       SW
# 158849 -77.020324  38.880130       SW
# 158859 -77.020324  38.880130       SW
# 158860 -77.020324  38.880130       SW
# 158863 -77.020324  38.880130       SW
# 158866 -77.020324  38.880130       SW
# 158872 -77.020324  38.880130       SW
# 158883 -77.020324  38.880130       SW
# 158913 -77.019277  38.914287       NW
# 158917 -77.019277  38.914287       NW
# 158922 -77.019277  38.914287       NW
# 158923 -77.019277  38.914287       NW
# 158925 -77.019277  38.914287       NW
# 158937 -77.019422  38.911848       NW
# 158941 -77.019422  38.911848       NW
# 158942 -77.019422  38.911848       NW
#
# [26770 rows x 49 columns]

# %%
df_missing.isnull().sum()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# LIVING_GBA            106696
# FULLADDRESS            52917
# CITY                   52906
# STATE                  52906
# ZIPCODE                    1
# NATIONALGRID           52906
# LATITUDE                   1
# LONGITUDE                  1
# ASSESSMENT_NBHD            1
# ASSESSMENT_SUBNBHD     32551
# CENSUS_TRACT               1
# CENSUS_BLOCK           52906
# WARD                       1
# SQUARE                     0
# X                        237
# Y                        237
# QUADRANT                 237
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# CMPLX_NUM             float64
# LIVING_GBA            float64
# FULLADDRESS            object
# CITY                   object
# STATE                  object
# ZIPCODE               float64
# NATIONALGRID           object
# LATITUDE              float64
# LONGITUDE             float64
# ASSESSMENT_NBHD        object
# ASSESSMENT_SUBNBHD     object
# CENSUS_TRACT          float64
# CENSUS_BLOCK           object
# WARD                   object
# SQUARE                 object
# X                     float64
# Y                     float64
# QUADRANT               object
# dtype: object

# %%
df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# LIVING_GBA             52261
# FULLADDRESS           106040
# CITY                  106051
# STATE                 106051
# ZIPCODE               158956
# NATIONALGRID          106051
# LATITUDE              158956
# LONGITUDE             158956
# ASSESSMENT_NBHD       158956
# ASSESSMENT_SUBNBHD    126406
# CENSUS_TRACT          158956
# CENSUS_BLOCK          106051
# WARD                  158956
# SQUARE                158957
# X                     158720
# Y                     158720
# QUADRANT              158720
# dtype: int64

# %%
df['PRICE'].std
# Out:
# <bound method Series.std of 0         1095000.0
# 1               NaN
# 2         2100000.0
# 3         1602000.0
# 4               NaN
# 5         1950000.0
# 6               NaN
# 7         1050000.0
# 8         1430000.0
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14        1325000.0
# 15              NaN
# 16        1240000.0
# 17              NaN
# 18              NaN
# 19         592250.0
# 20          33232.0
# 21              NaN
# 22         907400.0
# 23        1065000.0
# 24        1100000.0
# 25          20000.0
# 26              NaN
# 27         703700.0
# 28              NaN
# 29        1210000.0
#             ...
# 158927          NaN
# 158928     632400.0
# 158929     574000.0
# 158930     365000.0
# 158931     405000.0
# 158932     505000.0
# 158933     520000.0
# 158934     499900.0
# 158935     451000.0
# 158936     564900.0
# 158937          NaN
# 158938     660000.0
# 158939     380000.0
# 158940          NaN
# 158941          NaN
# 158942          NaN
# 158943     539000.0
# 158944     908500.0
# 158945     450000.0
# 158946     485355.0
# 158947     320000.0
# 158948     460000.0
# 158949     550000.0
# 158950     635000.0
# 158951     389000.0
# 158952     399900.0
# 158953     416000.0
# 158954     600000.0
# 158955     215100.0
# 158956          NaN
# Name: PRICE, Length: 158957, dtype: float64>

# %%
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# 25%         4.000000       2.000000    1918.000000   1985.000000
# 50%         6.000000       3.000000    1937.000000   2004.000000
# 75%         7.000000       3.000000    1960.000000   2010.000000
# max        48.000000      24.000000    2019.000000   2019.000000
#
#                  EYB        STORIES      ...              USECODE  \
# count  158957.000000  106652.000000      ...        158957.000000
# mean     1963.718024       2.091793      ...            14.252999
# std        24.923150       2.933323      ...             3.725736
# min      1800.000000       0.000000      ...            11.000000
# 25%      1954.000000       2.000000      ...            11.000000
# 50%      1963.000000       2.000000      ...            13.000000
# 75%      1975.000000       2.000000      ...            17.000000
# max      2018.000000     826.000000      ...           117.000000
#
#             LANDAREA     CMPLX_NUM    LIVING_GBA        ZIPCODE  \
# count  158957.000000  52261.000000  52261.000000  158956.000000
# mean     2473.282158   2371.544249    888.834542   20012.694563
# std      5059.046023   1114.272364    420.185822      15.627084
# min         0.000000   1001.000000      0.000000   20001.000000
# 25%       697.000000   1501.000000    616.000000   20007.000000
# 50%      1649.000000   2265.000000    783.000000   20011.000000
# 75%      3000.000000   2910.000000   1060.000000   20018.000000
# max    942632.000000   5621.000000   8553.000000   20392.000000
#
#             LATITUDE      LONGITUDE   CENSUS_TRACT              X  \
# count  158956.000000  158956.000000  158956.000000  158720.000000
# mean       38.914854     -77.016676    5348.216324     -77.016712
# std         0.031723       0.040938    3369.645953       0.040933
# min        38.819731     -77.113909     100.000000     -77.113135
# 25%        38.895425     -77.042892    2102.000000     -77.042894
# 50%        38.915337     -77.019596    5201.000000     -77.019581
# 75%        38.936075     -76.988626    8302.000000     -76.988842
# max        38.995540     -76.909758   11100.000000     -76.910511
#
#                    Y
# count  158720.000000
# mean       38.914846
# std         0.031682
# min        38.820576
# 25%        38.895432
# 50%        38.915229
# 75%        38.936077
# max        38.993646
#
# [8 rows x 26 columns]
