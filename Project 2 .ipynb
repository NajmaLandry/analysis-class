# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#load csv file with headers 
location = "Datasets/DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
#show the column names in the dataset
df.columns
#or print(df.columns)
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
#show the data type of each column
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
#descriptive statistics
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
#doesn't do anything on its own
df.groupby('ZIPCODE')

# %%
#add a stats or math function to it
df['PRICE'].groupby(df['ZIPCODE']).mean()
# Out:
# ZIPCODE
# 20001.0    5.215550e+05
# 20002.0    4.628894e+05
# 20003.0    5.992484e+05
# 20004.0    4.755701e+05
# 20005.0    2.813137e+06
# 20006.0    1.959069e+05
# 20007.0    9.794061e+05
# 20008.0    8.522766e+05
# 20009.0    6.215259e+05
# 20010.0    5.070154e+05
# 20011.0    4.259763e+05
# 20012.0    4.755227e+05
# 20015.0    7.703746e+05
# 20016.0    5.914537e+06
# 20017.0    4.087405e+05
# 20018.0    3.691101e+05
# 20019.0    2.302621e+05
# 20020.0    2.281464e+05
# 20024.0    3.808846e+05
# 20032.0    3.235769e+05
# 20036.0    4.015452e+05
# 20037.0    6.124601e+05
# 20052.0    5.378571e+05
# 20392.0    3.489169e+05
# Name: PRICE, dtype: float64

# %%
#add a stats or math function to it
df['PRICE'].groupby(df['ZIPCODE']).max()
# Out:
# ZIPCODE
# 20001.0      7000000.0
# 20002.0      7576980.0
# 20003.0      3300000.0
# 20004.0      2750000.0
# 20005.0     53969391.0
# 20006.0       378000.0
# 20007.0     23960287.0
# 20008.0     18000000.0
# 20009.0     12780000.0
# 20010.0      3152740.0
# 20011.0      5000000.0
# 20012.0      2853497.0
# 20015.0      3600000.0
# 20016.0    137427545.0
# 20017.0      5250000.0
# 20018.0      4069000.0
# 20019.0     11000000.0
# 20020.0     25100000.0
# 20024.0     11000000.0
# 20032.0     25000000.0
# 20036.0     11984000.0
# 20037.0      4750000.0
# 20052.0       975000.0
# 20392.0      1020000.0
# Name: PRICE, dtype: float64

# %%
#add a stats or math function to it
df['PRICE'].groupby(df['ZIPCODE']).min()
# Out:
# ZIPCODE
# 20001.0         1.0
# 20002.0        10.0
# 20003.0     15000.0
# 20004.0     75900.0
# 20005.0      6950.0
# 20006.0     44000.0
# 20007.0        10.0
# 20008.0         1.0
# 20009.0       250.0
# 20010.0        10.0
# 20011.0       250.0
# 20012.0      4156.0
# 20015.0     20000.0
# 20016.0      1000.0
# 20017.0      1000.0
# 20018.0         1.0
# 20019.0        10.0
# 20020.0       250.0
# 20024.0     17000.0
# 20032.0         1.0
# 20036.0      3270.0
# 20037.0     19000.0
# 20052.0    370000.0
# 20392.0     75000.0
# Name: PRICE, dtype: float64

# %%
#make a scatterplot
sns.lmplot(x='ZIPCODE', y='PRICE', data=df)

# %%
#make a scatterplot
sns.lmplot(x='PRICE', y='ZIPCODE', data=df)

# %%
#make a scatterplot
sns.lmplot(x='BATHRM', y='BEDRM', data=df)

# %%
#drop rows with any missing data
df_no_missing = df.dropna()
df_no_missing
#the result shows that there are zero rows that have all the data.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
#drop a column
df.drop('', axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-f16c9ea555b7> in <module>()
#       1 #drop a column
# ----> 2 df.drop('', axis=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
# selecting required columns
df2=df[['ZIPCODE', 'PRICE']]
df2
# Out:
#         ZIPCODE      PRICE
# 0       20009.0  1095000.0
# 1       20009.0        NaN
# 2       20009.0  2100000.0
# 3       20009.0  1602000.0
# 4       20009.0        NaN
# 5       20009.0  1950000.0
# 6       20009.0        NaN
# 7       20009.0  1050000.0
# 8       20009.0  1430000.0
# 9       20009.0        NaN
# 10      20009.0        NaN
# 11      20009.0        NaN
# 12      20009.0        NaN
# 13      20009.0        NaN
# 14      20009.0  1325000.0
# 15      20009.0        NaN
# 16      20009.0  1240000.0
# 17      20009.0        NaN
# 18      20009.0        NaN
# 19      20009.0   592250.0
# 20      20009.0    33232.0
# 21      20009.0        NaN
# 22      20009.0   907400.0
# 23      20009.0  1065000.0
# 24      20009.0  1100000.0
# 25      20009.0    20000.0
# 26      20009.0        NaN
# 27      20009.0   703700.0
# 28      20009.0        NaN
# 29      20009.0  1210000.0
# ...         ...        ...
# 158927  20001.0        NaN
# 158928  20001.0   632400.0
# ...

# %%
#Selecting rows with no missing zipcode or price
df2[df2['ZIPCODE'].notnull() & df2['PRICE'].notnull()]
# Out:
#         ZIPCODE      PRICE
# 0       20009.0  1095000.0
# 2       20009.0  2100000.0
# 3       20009.0  1602000.0
# 5       20009.0  1950000.0
# 7       20009.0  1050000.0
# 8       20009.0  1430000.0
# 14      20009.0  1325000.0
# 16      20009.0  1240000.0
# 19      20009.0   592250.0
# 20      20009.0    33232.0
# 22      20009.0   907400.0
# 23      20009.0  1065000.0
# 24      20009.0  1100000.0
# 25      20009.0    20000.0
# 27      20009.0   703700.0
# 29      20009.0  1210000.0
# 32      20009.0   130500.0
# 37      20009.0   339500.0
# 40      20009.0  1050000.0
# 41      20009.0  1550000.0
# 42      20009.0  1599900.0
# 43      20009.0  1700000.0
# 44      20009.0  1700000.0
# 45      20009.0   450000.0
# 46      20009.0   846000.0
# 48      20009.0   348500.0
# 50      20009.0   849000.0
# 52      20009.0  1312000.0
# 54      20009.0   390000.0
# 55      20009.0   772500.0
# ...         ...        ...
# 158918  20001.0   839000.0
# 158919  20001.0   915500.0
# ...

# %%
#show the data type of each column
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
# selecting required columns
df2=df[['BATHRM ,ROOMS', 'BEDRM', 'STORIES', 'SALEDATE', 'PRICE',
       'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
       'LIVING_GBA', 'ZIPCODE']]
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-a46aaf9ac678> in <module>()
#       2 df2=df[['BATHRM ,ROOMS', 'BEDRM', 'STORIES', 'SALEDATE', 'PRICE',
#       3        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
# ----> 4        'LIVING_GBA', 'ZIPCODE']]
#       5 df2
#       6
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
# ...

# %%
#boxplot showing stats for each characteristic
sns.boxplot(data=df2)

# %%
# selecting required columns
df2=df[['ZIPCODE', 'PRICE']]
df2

# %%
#Selecting rows with no missing zipcode or price
df3 = df2[df2['ZIPCODE'].notnull() & df2['PRICE'].notnull()]
df3

# %%
#create a histogram of the distribution of zipcodes
sns.distplot(df3['ZIPCODE'])

# %%
# I got error for the above command, so I need to eliminate empty cells
#create a histogram of the distribution of zipcodes
sns.distplot(df3['ZIPCODE'])

# %%
#create a histogram of the distribution of PRICE
sns.distplot(df3['PRICE'])

# %%
#create a bar plot of zipcode frequency
sns.countplot(x='ZIPCODE',
              data=df

# %%
# selecting required columns
df2=df[['ZIPCODE', 'PRICE']]
df2
